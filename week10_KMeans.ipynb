# %% [markdown]
# <a href="https://colab.research.google.com/github/9-coding/DataScience/blob/main/week10_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from pandas import DataFrame
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

Data = {'x': [25,34,22,27,33,33,31,22,35,34,67,54,57,43,50,57,59,52,65,47,49,48,35,33,44,45,38,43,51,46],
        'y': [79,51,53,78,59,74,73,57,69,75,51,32,40,47,53,36,35,58,59,50,25,20,14,12,20,5,29,27,8,7]
       }
  
df = DataFrame(Data,columns=['x','y'])
print (df)

def kmeans_clustering(k):
  print("\n\n", k, "clusters:")
  # Create 3 clusters
  kmeans = KMeans(n_clusters=k, n_init=10).fit(df)
  centroids = kmeans.cluster_centers_
  print(centroids)

  # Display the 3 clusters
  plt.scatter(df['x'], df['y'], c=kmeans.labels_.astype(float), s=50, alpha=0.5)
  plt.scatter(centroids[:,0], centroids[:,1], c='red', s=50)
  plt.show()

kmeans_clustering(3)

kmeans_clustering(4)
# Out:
#      x   y
# 0   25  79
# 1   34  51
# 2   22  53
# 3   27  78
# 4   33  59
# 5   33  74
# 6   31  73
# 7   22  57
# 8   35  69
# 9   34  75
# 10  67  51
# 11  54  32
# 12  57  40
# 13  43  47
# 14  50  53
# 15  57  36
# 16  59  35
# 17  52  58
# 18  65  59
# 19  47  50
# 20  49  25
# 21  48  20
# 22  35  14
# 23  33  12
# 24  44  20
# 25  45   5
# 26  38  29
# 27  43  27
# 28  51   8
# 29  46   7
#
#
#  3 clusters:
# [[43.2 16.7]
#  [29.6 66.8]
#  [55.1 46.1]]
#  4 clusters:
# [[43.2        16.7       ]
#  [29.11111111 68.55555556]
#  [58.8        38.8       ]
#  [48.5        53.        ]]
